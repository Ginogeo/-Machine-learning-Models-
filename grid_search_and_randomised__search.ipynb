# %% [markdown]
# <a href="https://colab.research.google.com/github/Ginogeo/ML/blob/ML_1/grid_search_and_randomised__search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Grid Search CV**

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
import sklearn.datasets
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
breast_cancer_dataset = sklearn.datasets.load_breast_cancer()
data = pd.DataFrame(breast_cancer_dataset.data, columns=breast_cancer_dataset.feature_names)
data['label']= breast_cancer_dataset.target
#print(data.head())
#print(data.isnull().sum())
#print(data['label'].value_counts())
x = data.drop(columns='label',axis=1)
y = data['label']
x = np.asarray(x)
y = np.asarray(y)
# grid search is used to determine the best parameter for our model
model = SVC()
parameters  = {
    'kernel':['linear', 'poly','rbf','sigmoid'],
    'C':[1, 5, 10, 20]
}

classifier = GridSearchCV(model, parameters,cv=5)
# fitting data
classifier.fit(x,y)
print(classifier.cv_results_)

# %%
best_parameter = classifier.best_params_
print(best_parameter)
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
result = pd.DataFrame(classifier.cv_results_)

# %%
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       1.441910      0.578726         0.001437        0.000147       1
# 1       0.004233      0.000156         0.001535        0.000053       1
# 2       0.005057      0.000121         0.002236        0.000244       1
# 3       0.016294      0.000443         0.004412        0.000144       1
# 4       5.860642      2.253046         0.001752        0.000346       5
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.947368
# 1         poly     {'C': 1, 'kernel': 'poly'}           0.842105
# 2          rbf      {'C': 1, 'kernel': 'rbf'}           0.850877
# 3      sigmoid  {'C': 1, 'kernel': 'sigmoid'}           0.543860
# 4       linear   {'C': 5, 'kernel': 'linear'}           0.947368
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %%
grid_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
grid_search_result
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.945536
# 1        1         poly         0.908663
# 2        1          rbf         0.912172
# 3        1      sigmoid         0.460441
# 4        5       linear         0.950815
# 5        5         poly         0.922729
# 6        5          rbf         0.931501
# 7        5      sigmoid         0.411178
# 8       10       linear         0.952569
# 9       10         poly         0.920975
# 10      10          rbf         0.922714
# 11      10      sigmoid         0.402391
# 12      20       linear         0.949061
# 13      20         poly         0.919221
# 14      20          rbf         0.920944
# 15      20      sigmoid         0.398867
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
# ...

# %% [markdown]
# highest accuracy  = 95.28
#
# best parameter = 'C': 10, 'kernel': 'linear'

# %% [markdown]
# #**Randomised Searh CV**

# %%
model = SVC()
parameters  = {
    'kernel':['linear', 'poly','rbf','sigmoid'],
    'C':[1, 5, 10, 20]
}

# %%
classifier = RandomizedSearchCV(model, parameters,cv=5)
classifier.fit(x,y)
print(classifier.cv_results_)
# Out:
# {'mean_fit_time': array([4.93069983e+00, 4.12354469e-03, 1.71747036e+00, 4.82695580e-02,
#        7.31167793e-03, 3.42026381e+00, 4.42028046e-03, 3.81832123e-03,
#        4.24766541e-03, 1.43917561e-02]), 'std_fit_time': array([1.08268818e+00, 3.64280951e-04, 8.03843934e-01, 8.56454624e-03,
#        3.36548295e-04, 1.02931407e+00, 1.36291455e-04, 2.58419847e-04,
#        3.42628121e-04, 5.68262260e-04]), 'mean_score_time': array([0.00144939, 0.00133457, 0.00161195, 0.01476836, 0.0033052 ,
#        0.0014061 , 0.00125694, 0.00136428, 0.00161505, 0.00368018]), 'std_score_time': array([2.19469419e-04, 4.75422669e-05, 3.30155003e-04, 4.73594861e-03,
#        2.53738848e-04, 2.60722271e-04, 7.21161620e-05, 4.01210796e-05,
#        7.00105105e-05, 4.71701142e-05]), 'param_kernel': masked_array(data=['linear', 'poly', 'linear', 'sigmoid', 'rbf', 'linear',
#                    'poly', 'poly', 'rbf', 'sigmoid'],
#              mask=[False, False, False, False, False, False, False, False,
# ...

# %%
result = pd.DataFrame(classifier.cv_results_)

# %%
best_parameter = classifier.best_params_
print(best_parameter)
highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# {'kernel': 'linear', 'C': 10}
# 0.9525694767893185

# %%
randomised_search_result = result[['param_C','param_kernel','mean_test_score']]
randomised_search_result
# Out:
#   param_C param_kernel  mean_test_score
# 0      10       linear         0.952569
# 1       5         poly         0.922729
# 2       1       linear         0.945536
# 3       1      sigmoid         0.460441
# 4      10          rbf         0.922714
# 5       5       linear         0.950815
# 6      20         poly         0.919221
# 7       1         poly         0.908663
# 8      20          rbf         0.920944
# 9      20      sigmoid         0.398867
